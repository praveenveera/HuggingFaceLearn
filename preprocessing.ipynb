# %% [markdown]
# ## Preprocessing the data

# %%
# imports
import tensorflow as tf
import numpy as np
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
# Out:
# 2023-12-25 18:31:18.843993: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-25 18:31:18.844018: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-25 18:31:18.844676: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-25 18:31:18.848719: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-25 18:31:19.462732: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
checkpoint = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint)
sequence = [
    "I have been waiting for a NLP course my whole life.",
    "This course is so good"
]
batch = dict(tokenizer(sequence, padding=True, truncation=True, return_tensors="tf"))

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy")
labels = tf.convert_to_tensor([1,1])
model.train_on_batch(batch, labels)
# Out:
# 2023-12-25 18:36:23.970548: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.00MiB (rounded to 9437184)requested by op AddV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-12-25 18:36:23.970623: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-12-25 18:36:23.970652: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 18, Chunks in use: 18. 4.5KiB allocated for chunks. 4.5KiB in use in bin. 108B client-requested in use in bin.
# 2023-12-25 18:36:23.970672: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-25 18:36:23.970692: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 2, Chunks in use: 1. 3.0KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2023-12-25 18:36:23.970714: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 160, Chunks in use: 160. 483.0KiB allocated for chunks. 483.0KiB in use in bin. 480.0KiB client-requested in use in bin.
# 2023-12-25 18:36:23.970734: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 13, Chunks in use: 10. 76.2KiB allocated for chunks. 58.2KiB in use in bin. 48.0KiB client-requested in use in bin.
# 2023-12-25 18:36:23.970754: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 16, Chunks in use: 16. 205.0KiB allocated for chunks. 205.0KiB in use in bin. 192.0KiB client-requested in use in bin.
# 2023-12-25 18:36:23.970774: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 3, Chunks in use: 3. 63.2KiB allocated for chunks. 63.2KiB in use in bin. 48.0KiB client-requested in use in bin.
# 2023-12-25 18:36:23.970790: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-25 18:36:23.970807: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 1, Chunks in use: 0. 72.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-25 18:36:23.970878: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-25 18:36:23.970895: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-25 18:36:23.970911: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-25 18:36:23.970929: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 3, Chunks in use: 1. 4.14MiB allocated for chunks. 1.50MiB in use in bin. 1.50MiB client-requested in use in bin.
# 2023-12-25 18:36:23.970951: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 75, Chunks in use: 73. 169.46MiB allocated for chunks. 164.96MiB in use in bin. 163.50MiB client-requested in use in bin.
# 2023-12-25 18:36:23.970969: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 1, Chunks in use: 1. 4.04MiB allocated for chunks. 4.04MiB in use in bin. 2.25MiB client-requested in use in bin.
# 2023-12-25 18:36:23.970990: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 36, Chunks in use: 36. 333.92MiB allocated for chunks. 333.92MiB in use in bin. 324.00MiB client-requested in use in bin.
# 2023-12-25 18:36:23.971010: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 16.24MiB allocated for chunks. 16.24MiB in use in bin. 9.00MiB client-requested in use in bin.
# 2023-12-25 18:36:23.971026: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-25 18:36:23.971047: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 2, Chunks in use: 2. 191.57MiB allocated for chunks. 191.57MiB in use in bin. 178.84MiB client-requested in use in bin.
# 2023-12-25 18:36:23.971072: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-25 18:36:23.971089: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-25 18:36:23.971107: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 9.00MiB was 8.00MiB, Chunk State:
# 2023-12-25 18:36:23.971123: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 755236864
# 2023-12-25 18:36:23.971142: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1aa2000000 of size 256 next 1
# 2023-12-25 18:36:23.971157: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1aa2000100 of size 1280 next 2
# 2023-12-25 18:36:23.971171: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1aa
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-12-25 18:36:23.976730: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] **************************************************************************************x*************
# 2023-12-25 18:36:23.976761: W tensorflow/core/framework/op_kernel.cc:1827] RESOURCE_EXHAUSTED: failed to allocate memory
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[3], line 3
#       1 checkpoint = 'bert-base-uncased'
#       2 tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# ----> 3 model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint)
#       4 sequence = [
#       5     "I have been waiting for a NLP course my whole life.",
#       6     "This course is so good"
#       7 ]
#       8 batch = dict(tokenizer(sequence, padding=True, truncation=True, return_tensors="tf"))
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:566, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     564 elif type(config) in cls._model_mapping.keys():
#     565     model_class = _get_model_class(config, cls._model_mapping)
# --> 566     return model_class.from_pretrained(
#     567         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     568     )
#     569 raise ValueError(
#     570     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     571     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     572 )
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/modeling_tf_utils.py:2919, in TFPreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, *model_args, **kwargs)
#    2917         model.build()  # build the network with dummy inputs
#    2918 else:
# -> 2919     model.build()  # build the network with dummy inputs
#    2921 if safetensors_from_pt:
#    2922     from .modeling_tf_pytorch_utils import load_pytorch_state_dict_in_tf2_model
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/modeling_tf_utils.py:1141, in TFPreTrainedModel.build(self, input_shape)
#    1138 # Set the serving spec quickly to ensure that Keras doesn't use the specific dummy input shapes as the spec
#    1139 # Setting it in build() allows users to override the shape when loading a non-pretrained model from config
#    1140 self._set_save_spec(self.input_signature)
# -> 1141 self(self.dummy_inputs, training=False)
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/modeling_tf_utils.py:426, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     423     config = self.config
#     425 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 426 return func(self, **unpacked_inputs)
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/models/bert/modeling_tf_bert.py:1569, in TFBertForSequenceClassification.call(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, labels, training)
#    1540 @unpack_inputs
#    1541 @add_start_docstrings_to_model_forward(BERT_INPUTS_DOCSTRING.format("batch_size, sequence_length"))
#    1542 @add_code_sample_docstrings(
#    (...)
#    1561     training: Optional[bool] = False,
#    1562 ) -> Union[TFSequenceClassifierOutput, Tuple[tf.Tensor]]:
#    1563     r"""
#    1564     labels (`tf.Tensor` or `np.ndarray` of shape `(batch_size,)`, *optional*):
#    1565         Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1566         config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1567         `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1568     """
# -> 1569     outputs = self.bert(
#    1570         input_ids=input_ids,
#    1571         attention_mask=attention_mask,
#    1572         token_type_ids=token_type_ids,
#    1573         position_ids=position_ids,
#    1574         head_mask=head_mask,
#    1575         inputs_embeds=inputs_embeds,
#    1576         output_attentions=output_attentions,
#    1577         output_hidden_states=output_hidden_states,
#    1578         return_dict=return_dict,
#    1579         training=training,
#    1580     )
#    1581     pooled_output = outputs[1]
#    1582     pooled_output = self.dropout(inputs=pooled_output, training=training)
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/modeling_tf_utils.py:426, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     423     config = self.config
#     425 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 426 return func(self, **unpacked_inputs)
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/models/bert/modeling_tf_bert.py:862, in TFBertMainLayer.call(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, training)
#     859 else:
#     860     head_mask = [None] * self.config.num_hidden_layers
# --> 862 encoder_outputs = self.encoder(
#     863     hidden_states=embedding_output,
#     864     attention_mask=extended_attention_mask,
#     865     head_mask=head_mask,
#     866     encoder_hidden_states=encoder_hidden_states,
#     867     encoder_attention_mask=encoder_extended_attention_mask,
#     868     past_key_values=past_key_values,
#     869     use_cache=use_cache,
#     870     output_attentions=output_attentions,
#     871     output_hidden_states=output_hidden_states,
#     872     return_dict=return_dict,
#     873     training=training,
#     874 )
#     876 sequence_output = encoder_outputs[0]
#     877 pooled_output = self.pooler(hidden_states=sequence_output) if self.pooler is not None else None
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/models/bert/modeling_tf_bert.py:554, in TFBertEncoder.call(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, training)
#     550     all_hidden_states = all_hidden_states + (hidden_states,)
#     552 past_key_value = past_key_values[i] if past_key_values is not None else None
# --> 554 layer_outputs = layer_module(
#     555     hidden_states=hidden_states,
#     556     attention_mask=attention_mask,
#     557     head_mask=head_mask[i],
#     558     encoder_hidden_states=encoder_hidden_states,
#     559     encoder_attention_mask=encoder_attention_mask,
#     560     past_key_value=past_key_value,
#     561     output_attentions=output_attentions,
#     562     training=training,
#     563 )
#     564 hidden_states = layer_outputs[0]
#     566 if use_cache:
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/models/bert/modeling_tf_bert.py:511, in TFBertLayer.call(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions, training)
#     508     present_key_value = present_key_value + cross_attn_present_key_value
#     510 intermediate_output = self.intermediate(hidden_states=attention_output)
# --> 511 layer_output = self.bert_output(
#     512     hidden_states=intermediate_output, input_tensor=attention_output, training=training
#     513 )
#     514 outputs = (layer_output,) + outputs  # add attentions if we output them
#     516 # if decoder, return the attn key/values as the last output
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/transformers/models/bert/modeling_tf_bert.py:430, in TFBertOutput.call(self, hidden_states, input_tensor, training)
#     429 def call(self, hidden_states: tf.Tensor, input_tensor: tf.Tensor, training: bool = False) -> tf.Tensor:
# --> 430     hidden_states = self.dense(inputs=hidden_states)
#     431     hidden_states = self.dropout(inputs=hidden_states, training=training)
#     432     hidden_states = self.LayerNorm(inputs=hidden_states + input_tensor)
#
# ResourceExhaustedError: Exception encountered when calling layer 'output' (type TFBertOutput).
#
# {{function_node __wrapped__AddV2_device_/job:localhost/replica:0/task:0/device:GPU:0}} failed to allocate memory [Op:AddV2] name:
#
# Call arguments received by layer 'output' (type TFBertOutput):
#   • hidden_states=tf.Tensor(shape=(1, 2, 3072), dtype=float32)
#   • input_tensor=tf.Tensor(shape=(1, 2, 768), dtype=float32)
#   • training=False
